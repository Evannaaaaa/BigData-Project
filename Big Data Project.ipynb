# %%
import pandas as pd

# %% [markdown]
# # Part 1 - Data Acquisition

# %%
# Read data from a CSV file into a data frame
df = pd.read_csv('Base.csv')

# Display the first ten rows of the data frame to examine if it is an individual-level data set
print(df.head(10))

# Display the variable list
print(df.columns.values)

# Display the number of rows and the number of columns in the data set to confirm the portrait shape
# The first element of the output is the number of rows and the second is the number of columns 
print(df.shape)
# Out:
#    fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0           1     0.9               0.166828                         -1
# 1           1     0.9               0.296286                         -1
# 2           1     0.9               0.044985                         -1
# 3           1     0.9               0.159511                         -1
# 4           1     0.9               0.596414                         -1
# 5           1     0.3               0.143921                         -1
# 6           1     0.7               0.321554                         -1
# 7           1     0.9               0.064817                         -1
# 8           1     0.7               0.065938                         -1
# 9           1     0.9               0.700096                         -1
#
#    current_address_months_count  customer_age  days_since_request  \
# 0                            88            50            0.020925
# 1                           144            50            0.005418
# 2                           132            40            3.108549
# 3                            22            50            0.019079
# 4                           218            50            0.004441
# 5                            30            30            0.028231
# 6                           152            30            0.030680
# 7                            18            50            0.034557
# 8                            64            40            0.020691
# 9                            60            40            0.016809
#
#    intended_balcon_amount payment_type  zip_count_4w  ...  has_other_cards  \
# 0               -1.331345           AA           769  ...                0
# 1               -0.816224           AB           366  ...                0
# 2               -0.755728           AC           870  ...                0
# 3               -1.205124           AB           810  ...                1
# 4               -0.773276           AB           890  ...                0
# 5               -0.748282           AD           732  ...                0
# 6               -0.278994           AB           876  ...                0
# 7               -1.265721           AB           901  ...                0
# 8               -1.442082           AB           933  ...                0
# 9               -1.070271           AB          1176  ...                0
#
#    proposed_credit_limit  foreign_request    source  \
# 0                  500.0                0  INTERNET
# 1                 1500.0                0  INTERNET
# 2                  200.0                0  INTERNET
# 3                  200.0                0  INTERNET
# 4                 1500.0                0  INTERNET
# 5                  200.0                0  INTERNET
# 6                 1500.0                0  INTERNET
# 7                  200.0                1  INTERNET
# 8                 1500.0                0  INTERNET
# 9                  200.0                0  INTERNET
#
#    session_length_in_minutes  device_os  keep_alive_session  \
# 0                   3.888115    windows                   0
# 1                  31.798819    windows                   0
# 2                   4.728705      other                   0
# 3                   2.047904      linux                   0
# 4                   3.775225  macintosh                   1
# 5                   4.815073    windows                   0
# 6                   1.558977    windows                   1
# 7                   2.637472      linux                   0
# 8                   2.175419    windows                   1
# 9                  24.040726    windows                   0
#
#    device_distinct_emails_8w device_fraud_count  month
# 0                          1                  0      7
# 1                          1                  0      7
# 2                          1                  0      7
# 3                          1                  0      7
# 4                          1                  0      7
# 5                          1                  0      7
# 6                          1                  0      7
# 7                          1                  0      7
# 8                          1                  0      7
# 9                          1                  0      7
#
# [10 rows x 32 columns]
# ['fraud_bool' 'income' 'name_email_similarity' 'prev_address_months_count'
#  'current_address_months_count' 'customer_age' 'days_since_request'
#  'intended_balcon_amount' 'payment_type' 'zip_count_4w' 'velocity_6h'
#  'velocity_24h' 'velocity_4w' 'bank_branch_count_8w'
#  'date_of_birth_distinct_emails_4w' 'employment_status'
#  'credit_risk_score' 'email_is_free' 'housing_status' 'phone_home_valid'
#  'phone_mobile_valid' 'bank_months_count' 'has_other_cards'
#  'proposed_credit_limit' 'foreign_request' 'source'
#  'session_length_in_minutes' 'device_os' 'keep_alive_session'
#  'device_distinct_emails_8w' 'device_fraud_count' 'month']
# (1000000, 32)

# %% [markdown]
# # Part 2 - Data Exploration

# %%
import seaborn as sns

# %%
# Draw a heat map for all the numerical variables in the data frame
df4heatmaps = df

# Compute the correlation matrix 
corr = df4heatmaps.corr()
# Print the correlation matrix
print(corr)
# Out:
#                                   fraud_bool    income  name_email_similarity  \
# fraud_bool                          1.000000  0.045079              -0.036720
# income                              0.045079  1.000000              -0.038519
# name_email_similarity              -0.036720 -0.038519               1.000000
# prev_address_months_count          -0.026031  0.018209              -0.018186
# current_address_months_count        0.033701 -0.036985               0.050305
# customer_age                        0.062959  0.125822              -0.048902
# days_since_request                  0.000567 -0.015877              -0.007736
# intended_balcon_amount             -0.024524  0.059046               0.029040
# zip_count_4w                        0.005212 -0.080581               0.025114
# velocity_6h                        -0.016892 -0.096431               0.024881
# velocity_24h                       -0.011183 -0.101269               0.035221
# velocity_4w                        -0.011536 -0.106333               0.039968
# bank_branch_count_8w               -0.011577  0.007474              -0.001470
# date_of_birth_distinct_emails_4w   -0.043224 -0.062348               0.022994
# credit_risk_score                   0.070624  0.171447               0.049126
# email_is_free                       0.027758 -0.024900              -0.066897
# phone_home_valid                   -0.035128  0.024938              -0.002931
# phone_mobile_valid                 -0.013180  0.014979               0.008966
# bank_months_count                  -0.003222 -0.004514              -0.006351
# has_other_cards                    -0.035156  0.086861               0.011021
# proposed_credit_limit               0.068907  0.108868               0.073159
# foreign_request                     0.016885  0.011452              -0.015224
# session_length_in_minutes           0.008999 -0.055430               0.005998
# keep_alive_session                 -0.050296 -0.043584               0.014342
# device_distinct_emails_8w           0.035704 -0.009992              -0.017804
# device_fraud_count                       NaN       NaN                    NaN
# month                               0.013250  0.116479              -0.042949
#
#                                   prev_address_months_count  \
# fraud_bool                                        -0.026031
# income                                             0.018209
# name_email_similarity                             -0.018186
# prev_address_months_count                          1.000000
# current_address_months_count                      -0.271730
# customer_age                                      -0.069178
# days_since_request                                 0.078107
# intended_balcon_amount                            -0.009428
# zip_count_4w                                      -0.029638
# velocity_6h                                       -0.001265
# velocity_24h                                       0.009020
# velocity_4w                                        0.005413
# bank_branch_count_8w                              -0.040628
# date_of_birth_distinct_emails_4w                   0.059560
# credit_risk_score                                 -0.016104
# email_is_free                                     -0.014348
# phone_home_valid                                  -0.053353
# phone_mobile_valid                                 0.004757
# bank_months_count                                 -0.045550
# has_other_cards                                   -0.042949
# proposed_credit_limit                             -0.028474
# foreign_request                                    0.019242
# session_length_in_minutes                          0.051425
# keep_alive_session                                 0.031672
# device_distinct_emails_8w                          0.011924
# device_fraud_count                                      NaN
# month                                             -0.001793
#
#                                   current_address_months_count  customer_age  \
# fraud_bool                                            0.033701      0.062959
# income                                               -0.036985      0.125822
# name_email_similarity                                 0.050305     -0.048902
# prev_address_months_count                            -0.271730     -0.069178
# current_address_months_count                          1.000000      0.142863
# customer_age                                          0.142863      1.000000
# days_since_request                                   -0.057836     -0.035999
# intended_balcon_amount                                0.057601     -0.013000
# zip_count_4w                                          0.047286     -0.014176
# velocity_6h                                           0.027508     -0.022063
# velocity_24h                                          0.018753     -0.010030
# velocity_4w                                           0.026172     -0.004303
# bank_branch_count_8w                                  0.054202      0.048412
# date_of_birth_distinct_emails_4w                     -0.174714     -0.420173
# credit_risk_score                                     0.094976      0.166094
# email_is_free                                        -0.079519     -0.000357
# phone_home_valid                                      0.129102      0.212713
# phone_mobile_valid                                   -0.088268     -0.147098
# bank_months_count                                     0.071997      0.012907
# has_other_cards                                       0.060732      0.108743
# proposed_credit_limit                                 0.130594      0.148857
# foreign_request                                      -0.012355     -0.001606
# session_length_in_minutes                            -0.033574      0.025049
# keep_alive_session                                   -0.050539     -0.024272
# device_distinct_emails_8w                            -0.000760      0.025709
# device_fraud_count                                         NaN           NaN
# month                                                -0.024541      0.005694
#
#                                   days_since_request  intended_balcon_amount  \
# fraud_bool                                  0.000567               -0.024524
# income                                     -0.015877                0.059046
# name_email_similarity                      -0.007736                0.029040
# prev_address_months_count                   0.078107               -0.009428
# current_address_months_count               -0.057836                0.057601
# customer_age                               -0.035999               -0.013000
# days_since_request                          1.000000                0.019782
# intended_balcon_amount                      0.019782                1.000000
# zip_count_4w                                0.000249                0.002251
# velocity_6h                                 0.027968                0.042849
# velocity_24h                                0.023869                0.064080
# velocity_4w                                 0.017706                0.051407
# bank_branch_count_8w                       -0.018173                0.102919
# date_of_birth_distinct_emails_4w            0.018731               -0.027343
# credit_risk_score                          -0.088141                0.002058
# email_is_free                               0.008163               -0.014754
# phone_home_valid                           -0.042009                0.000019
# phone_mobile_valid                          0.005130                0.038625
# bank_months_count                          -0.027460                0.178374
# has_other_cards                            -0.048861                0.096676
# proposed_credit_limit                      -0.068670                0.057860
# foreign_request                             0.001066                0.007933
# session_length_in_minutes                   0.049613                0.022811
# keep_alive_session                          0.000337               -0.020689
# device_distinct_emails_8w                   0.009025               -0.019910
# device_fraud_count                               NaN                     NaN
# month                                      -0.017938               -0.043070
#
#                                   zip_count_4w  velocity_6h  ...  \
# fraud_bool                            0.005212    -0.016892  ...
# income                               -0.080581    -0.096431  ...
# name_email_similarity                 0.025114     0.024881  ...
# prev_address_months_count            -0.029638    -0.001265  ...
# current_address_months_count          0.047286     0.027508  ...
# customer_age                         -0.014176    -0.022063  ...
# days_since_request                    0.000249     0.027968  ...
# intended_balcon_amount                0.002251     0.042849  ...
# zip_count_4w                          1.000000     0.142372  ...
# velocity_6h                           0.142372     1.000000  ...
# velocity_24h                          0.201186     0.464003  ...
# velocity_4w                           0.302955     0.400254  ...
# bank_branch_count_8w                  0.005958     0.020140  ...
# date_of_birth_distinct_emails_4w      0.126885     0.118752  ...
# credit_risk_score                    -0.102645    -0.145254  ...
# email_is_free                         0.021731     0.028379  ...
# phone_home_valid                     -0.035661    -0.036820  ...
# phone_mobile_valid                    0.012122    -0.010751  ...
# bank_months_count                     0.053637     0.014874  ...
# has_other_cards                      -0.015015    -0.007049  ...
# proposed_credit_limit                -0.011651    -0.025005  ...
# foreign_request                       0.017212    -0.000450  ...
# session_length_in_minutes             0.039687     0.054491  ...
# keep_alive_session                    0.022283     0.002797  ...
# device_distinct_emails_8w             0.020550     0.030030  ...
# device_fraud_count                         NaN          NaN  ...
# month                                -0.287203    -0.409148  ...
#
#                                   phone_mobile_valid  bank_months_count  \
# fraud_bool                                 -0.013180          -0.003222
# income                                      0.014979          -0.004514
# name_email_similarity                       0.008966          -0.006351
# prev_address_months_count                   0.004757          -0.045550
# current_address_months_count               -0.088268           0.071997
# customer_age                               -0.147098           0.012907
# days_since_request                          0.005130          -0.027460
# intended_balcon_amount                      0.038625           0.178374
# zip_count_4w                                0.012122           0.053637
# velocity_6h                                -0.010751           0.014874
# velocity_24h                               -0.029432           0.018855
# velocity_4w                                -0.027258           0.032344
# bank_branch_count_8w                       -0.011666           0.142625
# date_of_birth_distinct_emails_4w            0.093366          -0.009012
# credit_risk_score                           0.004166          -0.061105
# email_is_free                               0.031740           0.007207
# phone_home_valid                           -0.272392           0.053329
# phone_mobile_valid                          1.000000           0.005741
# bank_months_count                           0.005741           1.000000
# has_other_cards                             0.005268           0.005677
# proposed_credit_limit                      -0.021689          -0.023671
# foreign_request                             0.002743          -0.003140
# session_length_in_minutes                  -0.002933           0.017387
# keep_alive_session                          0.022710           0.002277
# device_distinct_emails_8w                  -0.040026           0.003301
# device_fraud_count                               NaN                NaN
# month                                       0.033656          -0.025015
#
#                                   has_other_cards  proposed_credit_limit  \
# fraud_bool                              -0.035156               0.068907
# income                                   0.086861               0.108868
# name_email_similarity                    0.011021               0.073159
# prev_address_months_count               -0.042949              -0.028474
# current_address_months_count             0.060732               0.130594
# customer_age                             0.108743               0.148857
# days_since_request                      -0.048861              -0.068670
# intended_balcon_amount                   0.096676               0.057860
# zip_count_4w                            -0.015015              -0.011651
# velocity_6h                             -0.007049              -0.025005
# velocity_24h                            -0.030688               0.017725
# velocity_4w                             -0.048343               0.052440
# bank_branch_count_8w                     0.040665               0.009072
# date_of_birth_distinct_emails_4w        -0.050281              -0.044810
# credit_risk_score                        0.139486               0.606141
# email_is_free                           -0.032058              -0.021247
# phone_home_valid                         0.106590               0.006359
# phone_mobile_valid                       0.005268              -0.021689
# bank_months_count                        0.005677              -0.023671
# has_other_cards                          1.000000               0.096254
# proposed_credit_limit                    0.096254               1.000000
# foreign_request                          0.001430               0.023947
# session_length_in_minutes               -0.092790              -0.000165
# keep_alive_session                      -0.098102              -0.021951
# device_distinct_emails_8w               -0.028367              -0.017452
# device_fraud_count                            NaN                    NaN
# month                                    0.043502              -0.056665
#
#                                   foreign_request  session_length_in_minutes  \
# fraud_bool                               0.016885                   0.008999
# income                                   0.011452                  -0.055430
# name_email_similarity                   -0.015224                   0.005998
# prev_address_months_count                0.019242                   0.051425
# current_address_months_count            -0.012355                  -0.033574
# customer_age                            -0.001606                   0.025049
# days_since_request                       0.001066                   0.049613
# intended_balcon_amount                   0.007933                   0.022811
# zip_count_4w                             0.017212                   0.039687
# velocity_6h                             -0.000450                   0.054491
# velocity_24h                             0.015419                   0.066875
# velocity_4w                              0.020785                   0.079005
# bank_branch_count_8w                    -0.002182                   0.004887
# date_of_birth_distinct_emails_4w         0.027282                  -0.029908
# credit_risk_score                        0.016265                  -0.034430
# email_is_free                            0.028850                   0.041251
# phone_home_valid                        -0.003037                  -0.043938
# phone_mobile_valid                       0.002743                  -0.002933
# bank_months_count                       -0.003140                   0.017387
# has_other_cards                          0.001430                  -0.092790
# proposed_credit_limit                    0.023947                  -0.000165
# foreign_request                          1.000000                   0.012497
# session_length_in_minutes                0.012497                   1.000000
# keep_alive_session                      -0.015308                  -0.051311
# device_distinct_emails_8w                0.009091                   0.077473
# device_fraud_count                            NaN                        NaN
# month                                   -0.018510                  -0.079542
#
#                                   keep_alive_session  \
# fraud_bool                                 -0.050296
# income                                     -0.043584
# name_email_similarity                       0.014342
# prev_address_months_count                   0.031672
# current_address_months_count               -0.050539
# customer_age                               -0.024272
# days_since_request                          0.000337
# intended_balcon_amount                     -0.020689
# zip_count_4w                                0.022283
# velocity_6h                                 0.002797
# velocity_24h                               -0.000567
# velocity_4w                                 0.022375
# bank_branch_count_8w                       -0.001437
# date_of_birth_distinct_emails_4w            0.037507
# credit_risk_score                          -0.031135
# email_is_free                              -0.022930
# phone_home_valid                            0.041755
# phone_mobile_valid                          0.022710
# bank_months_count                           0.002277
# has_other_cards                            -0.098102
# proposed_credit_limit                      -0.021951
# foreign_request                            -0.015308
# session_length_in_minutes                  -0.051311
# keep_alive_session                          1.000000
# device_distinct_emails_8w                  -0.034881
# device_fraud_count                               NaN
# month                                      -0.022076
#
#                                   device_distinct_emails_8w  \
# fraud_bool                                         0.035704
# income                                            -0.009992
# name_email_similarity                             -0.017804
# prev_address_months_count                          0.011924
# current_address_months_count                      -0.000760
# customer_age                                       0.025709
# days_since_request                                 0.009025
# intended_balcon_amount                            -0.019910
# zip_count_4w                                       0.020550
# velocity_6h                                        0.030030
# velocity_24h                                       0.034981
# velocity_4w                                        0.042320
# bank_branch_count_8w                               0.003697
# date_of_birth_distinct_emails_4w                  -0.008344
# credit_risk_score                                 -0.040987
# email_is_free                                      0.001959
# phone_home_valid                                   0.005301
# phone_mobile_valid                                -0.040026
# bank_months_count                                  0.003301
# has_other_cards                                   -0.028367
# proposed_credit_limit                             -0.017452
# foreign_request                                    0.009091
# session_length_in_minutes                          0.077473
# keep_alive_session                                -0.034881
# device_distinct_emails_8w                          1.000000
# device_fraud_count                                      NaN
# month                                             -0.046994
#
#                                   device_fraud_count     month
# fraud_bool                                       NaN  0.013250
# income                                           NaN  0.116479
# name_email_similarity                            NaN -0.042949
# prev_address_months_count                        NaN -0.001793
# current_address_months_count                     NaN -0.024541
# customer_age                                     NaN  0.005694
# days_since_request                               NaN -0.017938
# intended_balcon_amount                           NaN -0.043070
# zip_count_4w                                     NaN -0.287203
# velocity_6h                                      NaN -0.409148
# velocity_24h                                     NaN -0.549919
# velocity_4w                                      NaN -0.848100
# bank_branch_count_8w                             NaN -0.029182
# date_of_birth_distinct_emails_4w                 NaN -0.244779
# credit_risk_score                                NaN  0.175893
# email_is_free                                    NaN -0.064541
# phone_home_valid                                 NaN  0.057643
# phone_mobile_valid                               NaN  0.033656
# bank_months_count                                NaN -0.025015
# has_other_cards                                  NaN  0.043502
# proposed_credit_limit                            NaN -0.056665
# foreign_request                                  NaN -0.018510
# session_length_in_minutes                        NaN -0.079542
# keep_alive_session                               NaN -0.022076
# device_distinct_emails_8w                        NaN -0.046994
# device_fraud_count                               NaN       NaN
# month                                            NaN  1.000000
#
# [27 rows x 27 columns]

# %%
# Draw the heatmap
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Part 3 Missing Value Imputation

# %%
# Show the number of missing values for each variable in the data frame
df.isnull().sum()
# Out:
# fraud_bool                          0
# income                              0
# name_email_similarity               0
# prev_address_months_count           0
# current_address_months_count        0
# customer_age                        0
# days_since_request                  0
# intended_balcon_amount              0
# payment_type                        0
# zip_count_4w                        0
# velocity_6h                         0
# velocity_24h                        0
# velocity_4w                         0
# bank_branch_count_8w                0
# date_of_birth_distinct_emails_4w    0
# employment_status                   0
# credit_risk_score                   0
# email_is_free                       0
# housing_status                      0
# phone_home_valid                    0
# phone_mobile_valid                  0
# bank_months_count                   0
# has_other_cards                     0
# proposed_credit_limit               0
# foreign_request                     0
# source                              0
# session_length_in_minutes           0
# device_os                           0
# keep_alive_session                  0
# device_distinct_emails_8w           0
# device_fraud_count                  0
# month                               0
# dtype: int64

# %%
# Drop 'device_fraud_count' since it contains the same value for all
rvar_list =['device_fraud_count']
df_sample1 = df.drop(columns=rvar_list)

# %%
# Separate all the variables into two lists for future column indexing
# One for numerical, the other for categorical (12 categorical + 19 numerical)
cvar_list = ['fraud_bool', 'payment_type', 'employment_status', 'email_is_free',
 'housing_status', 'phone_home_valid',
 'phone_mobile_valid', 'has_other_cards',
 'foreign_request', 'source',
 'device_os', 'keep_alive_session']
nvar_list = ['income', 'name_email_similarity', 'prev_address_months_count',
 'current_address_months_count', 'customer_age', 'days_since_request',
 'intended_balcon_amount', 'zip_count_4w', 'velocity_6h',
 'velocity_24h', 'velocity_4w', 'bank_branch_count_8w',
 'date_of_birth_distinct_emails_4w',
 'credit_risk_score',
 'bank_months_count',
 'proposed_credit_limit',
 'session_length_in_minutes',
 'device_distinct_emails_8w', 'month']

# Get the unique values of each categorical variables in the data frame
def column_unique_values(x_column):
  return list(x_column.unique())

df_sample1[cvar_list].apply(column_unique_values)
# Out:
# fraud_bool                                             [1, 0]
# payment_type                             [AA, AB, AC, AD, AE]
# employment_status                [CA, CB, CC, CD, CE, CF, CG]
# email_is_free                                          [0, 1]
# housing_status                   [BA, BB, BC, BD, BE, BF, BG]
# phone_home_valid                                       [1, 0]
# phone_mobile_valid                                     [0, 1]
# has_other_cards                                        [0, 1]
# foreign_request                                        [0, 1]
# source                                    [INTERNET, TELEAPP]
# device_os             [windows, other, linux, macintosh, x11]
# keep_alive_session                                     [0, 1]
# dtype: object

# %% [markdown]
# # Part 4 - Variable transformation

# %%
# Standardize the numerical variables 
df_sample2 = df_sample1.copy()
df_sample2[nvar_list] = (df_sample1[nvar_list] - df_sample1[nvar_list].mean())/df_sample1[nvar_list].std()

# Set the datatype for the variables in the cvar_list to be categorical in Python
# Set the datatype for the variables in the nvar_list to be numerical in Python 
df_sample3 = df_sample2.copy()
df_sample3[cvar_list] = df_sample2[cvar_list].astype('category')
df_sample3[nvar_list] = df_sample2[nvar_list].astype('float64')

# Convert the categorical variables into dummies (Step 1 of dummy coding)
# prefix_sep is the sympol used to create the dummy variable names.
df_sample4 = df_sample3.copy()
df_sample4 = pd.get_dummies(df_sample3, prefix_sep='-')
print(df_sample4.columns.values)
# Out:
# ['income' 'name_email_similarity' 'prev_address_months_count'
#  'current_address_months_count' 'customer_age' 'days_since_request'
#  'intended_balcon_amount' 'zip_count_4w' 'velocity_6h' 'velocity_24h'
#  'velocity_4w' 'bank_branch_count_8w' 'date_of_birth_distinct_emails_4w'
#  'credit_risk_score' 'bank_months_count' 'proposed_credit_limit'
#  'session_length_in_minutes' 'device_distinct_emails_8w' 'month'
#  'fraud_bool-0' 'fraud_bool-1' 'payment_type-AA' 'payment_type-AB'
#  'payment_type-AC' 'payment_type-AD' 'payment_type-AE'
#  'employment_status-CA' 'employment_status-CB' 'employment_status-CC'
#  'employment_status-CD' 'employment_status-CE' 'employment_status-CF'
#  'employment_status-CG' 'email_is_free-0' 'email_is_free-1'
#  'housing_status-BA' 'housing_status-BB' 'housing_status-BC'
#  'housing_status-BD' 'housing_status-BE' 'housing_status-BF'
#  'housing_status-BG' 'phone_home_valid-0' 'phone_home_valid-1'
#  'phone_mobile_valid-0' 'phone_mobile_valid-1' 'has_other_cards-0'
#  'has_other_cards-1' 'foreign_request-0' 'foreign_request-1'
#  'source-INTERNET' 'source-TELEAPP' 'device_os-linux'
#  'device_os-macintosh' 'device_os-other' 'device_os-windows'
#  'device_os-x11' 'keep_alive_session-0' 'keep_alive_session-1']

# %%
# Remove the redundant dummies (Step 2 of dummy coding)
rdummies = ['fraud_bool-0','payment_type-AA',
 'employment_status-CA', 'email_is_free-0',
 'housing_status-BA', 'phone_home_valid-0',
 'phone_mobile_valid-0', 'has_other_cards-0',
 'foreign_request-0',
 'source-INTERNET', 'device_os-linux',
 'keep_alive_session-0']
df_sample5 = df_sample4.copy()
df_sample5 = df_sample4.drop(columns=rdummies)

# Get the remaining variable list after the variable transformation
print(df_sample5.columns.values)
# Out:
# ['income' 'name_email_similarity' 'prev_address_months_count'
#  'current_address_months_count' 'customer_age' 'days_since_request'
#  'intended_balcon_amount' 'zip_count_4w' 'velocity_6h' 'velocity_24h'
#  'velocity_4w' 'bank_branch_count_8w' 'date_of_birth_distinct_emails_4w'
#  'credit_risk_score' 'bank_months_count' 'proposed_credit_limit'
#  'session_length_in_minutes' 'device_distinct_emails_8w' 'month'
#  'fraud_bool-1' 'payment_type-AB' 'payment_type-AC' 'payment_type-AD'
#  'payment_type-AE' 'employment_status-CB' 'employment_status-CC'
#  'employment_status-CD' 'employment_status-CE' 'employment_status-CF'
#  'employment_status-CG' 'email_is_free-1' 'housing_status-BB'
#  'housing_status-BC' 'housing_status-BD' 'housing_status-BE'
#  'housing_status-BF' 'housing_status-BG' 'phone_home_valid-1'
#  'phone_mobile_valid-1' 'has_other_cards-1' 'foreign_request-1'
#  'source-TELEAPP' 'device_os-macintosh' 'device_os-other'
#  'device_os-windows' 'device_os-x11' 'keep_alive_session-1']

# %% [markdown]
# # Part 5 - Data Partiton

# %%
from sklearn.model_selection import train_test_split

# test_size specifies the percentage for the test partition
df4partition = df_sample5
testpart_size = 0.2

# random_state specifies the seed for random number generator. 
# random_state = 1 unless otherwised noted
df_nontestData, df_testData = train_test_split(df4partition, test_size=testpart_size, random_state=1)

# %% [markdown]
# # Part 6 - Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV

# Separate the predictor values and the DV values into X and y respectively
DV = 'fraud_bool-1'
y = df_nontestData[DV]
X = df_nontestData.drop(columns=[DV])

# A user-defined function summary_coef
# to display the estimated coefficients of a model candidate obtained by the Logistic Regression analysis
def summary_coef(model_object):
  n_predictors = X.shape[1]
  model_coef = pd.DataFrame(model_object.coef_.reshape(1, n_predictors), columns=X.columns.values)
  model_coef['Intercept'] = model_object.intercept_
  return model_coef.transpose()

# %%
# Run Logistic regression with k-fold cross validation with k=5
kfolds = 5

# Here we specify within which range of the penalty levels we will search for the optimal penalty level, 
# i.e., the level that leads to the best model candidate
# We search the optimal alpha within [min_alpha, max_alpha]
min_alpha = 0.001
max_alpha = 100

# We further discretize the continuous alpha range [min_alpha, max_alpha] into n individual points of alpha
# We train n model candidates each of which corresponds to one individual alpha point
n_candidates = 1000

import numpy as np

# We store the list of individual alpha points into alpha_list
alpha_list = list(np.linspace(min_alpha, max_alpha, num=n_candidates))

# C_list is the element-wise inverse of alpha_list. It is required as one of the paramater values for LogisticRegressionCV
C_list = list(1/np.linspace(min_alpha, max_alpha, num=n_candidates))

# Set n_jobs to be -1 to run LogisticRegressionCV on all CPU cores.
clf_optimal = LogisticRegressionCV(Cs=C_list, cv=kfolds, penalty='l1', solver='saga', max_iter=4000, random_state=1, n_jobs=-1).fit(X,y)

# Display the estimated coefficients of the final selected model
print(summary_coef(clf_optimal))
# Out:
#                                          0
# income                            0.284018
# name_email_similarity            -0.348506
# prev_address_months_count        -0.356059
# current_address_months_count      0.020724
# customer_age                      0.251899
# days_since_request                0.045202
# intended_balcon_amount           -0.162510
# zip_count_4w                      0.110875
# velocity_6h                      -0.027485
# velocity_24h                      0.036334
# velocity_4w                       0.000000
# bank_branch_count_8w             -0.052217
# date_of_birth_distinct_emails_4w -0.151051
# credit_risk_score                 0.186450
# bank_months_count                 0.147468
# proposed_credit_limit             0.146635
# session_length_in_minutes         0.008261
# device_distinct_emails_8w         0.155884
# month                             0.092953
# payment_type-AB                   0.000000
# payment_type-AC                   0.671688
# payment_type-AD                   0.045124
# payment_type-AE                   0.000000
# employment_status-CB             -0.476472
# employment_status-CC              0.175586
# employment_status-CD             -0.458441
# employment_status-CE             -0.478045
# employment_status-CF             -0.919768
# employment_status-CG              0.000000
# email_is_free-1                   0.593568
# housing_status-BB                -1.109788
# housing_status-BC                -1.085012
# housing_status-BD                -0.740161
# housing_status-BE                -1.289124
# housing_status-BF                 0.000000
# housing_status-BG                 0.000000
# phone_home_valid-1               -0.919990
# phone_mobile_valid-1             -0.226169
# has_other_cards-1                -1.175256
# foreign_request-1                 0.456964
# source-TELEAPP                    0.370269
# device_os-macintosh               0.689974
# device_os-other                   0.169907
# device_os-windows                 1.156809
# device_os-x11                     0.240752
# keep_alive_session-1             -0.669542
# Intercept                        -4.288993

# %%
# Display the optimal alpha that yields the final selected model (the best model candidate)
print(1/clf_optimal.C_)
# Out:
# [15.41626126]

# %%
# Calcuate the error rate over the test partition based on the final selected model

# y_test_actual is the actual values of the DV in the test partition
y_test_actual = df_testData[DV]

# X_test is the predictor values in the test partition
X_test = df_testData.drop(columns=[DV])

# Use predict method of the clf_optimal object to apply the model associated with clf_optimal to the test partition
# y_test_predicted is the predicted values of the DV in the test partition 
y_test_predicted = clf_optimal.predict(X_test)

# Import the metrics package
from sklearn import metrics

# Display the confusion matrix over the test partition
print(metrics.confusion_matrix(y_test_actual, y_test_predicted))

print(metrics.classification_report(y_test_actual,y_test_predicted))

# Display the accuracy over the test partition
print(clf_optimal.score(X_test, y_test_actual))
# Out:
# [[197674     11]
#  [  2282     33]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99    197685
#            1       0.75      0.01      0.03      2315
#
#     accuracy                           0.99    200000
#    macro avg       0.87      0.51      0.51    200000
# weighted avg       0.99      0.99      0.98    200000
#
# 0.988535

# %% [markdown]
# # Part 7 - Classification Tree

# %%
# Regarding the decision cut-off value:
# choose 0.5 to maximize the accuracy
# In order to maximize the bank's profits/minimize the bank's loss, we are thinking about creating a senario:
# Set actually fraud, but not detected, -500 ----- average of the proposed_credit_limit
# Set actually not-fraud, but detected, -100 ----- considering costs of 
#                                                1)customer service to unfrozen card; 
#                                                2)loss in bank's goodwill.
# Set actually fraud, detected, 2000
# Set actually non-fraud, not detected, 0
# 2000x - 100(1-x) > -500x
# x > 1/24

# %%
max_proposed_credit_limit = df['proposed_credit_limit'].max()
max_proposed_credit_limit
# Out:
# 2100.0

# %%
mean_proposed_credit_limit = df['proposed_credit_limit'].mean()
mean_proposed_credit_limit
# Out:
# 515.85101

# %%
# Create a user-defined function, profit_calcuation, that calcuates the profit over a dataset 
# for which we know the actual class (e.g., fraud/not-fraud) from y_value
# and the predictors values (e.g. income, customer_age) from x_value
# using the probability prediction model carried by the model object model.

def profit_calculation(model, x_value, y_value):
  
    # Specify the decision cut-off used in the decision rule
    d_cutoff = 1/24

    # Get the decisions made by the decision rule for each observation in the dataset
    # The method predict_proba is to get the predicted probability
    # Then we compare the predicted probabilities with the decision cut-off d_cutoff
    # True means DETECTED, False means NOT DETECTED
    # list() is to convert the results into a Python list
    decision = list(model.predict_proba(x_value)[:,1] > d_cutoff)
  
    # We put the actual class into a Python list called y
    y = list(y_value)
  
    # Get the number of observations of the dataset and put it into n_obs
    n_obs = len(y)

    # cum_profit is for cumulating the profit during the for-loop
    cum_profit = 0

    for i in range(n_obs): # i will go from 0 to (n_obs-1)
        if decision[i] == True and y[i] == 1: # if the decision is DETECTED and the actual class is 1 (FRAUD) for the i-th observation
            profit = 2000 # the net profit is 2000
        elif decision[i] == True and y[i] == 0: # if the decision is DETECTED and the actual class is 0 (NON-FRAUD) for the i-th observation
            profit = -100 # the net profit is -100
        elif decision[i] == False and y[i] == 1: # if the decision is NOT-DETECTED and the actual class is 1 (FRAUD) for the i-th observation
            profit = -500 # the net profit is -500
        else:
            profit = 0 # For any other situation, the net profit is zero
        cum_profit = cum_profit + profit # cumulating the profit
  
    average_net_profit = cum_profit / n_obs # Derive the average net profit
    return average_net_profit # return the average net profit

# %%
pip install pydotplus
# Out:
# Collecting pydotplus
#   Downloading pydotplus-2.0.2.tar.gz (278 kB)
#      |████████████████████████████████| 278 kB 7.2 MB/s eta 0:00:01
# Requirement already satisfied: pyparsing>=2.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from pydotplus) (3.0.4)
# Building wheels for collected packages: pydotplus
#   Building wheel for pydotplus (setup.py) ... done
#   Created wheel for pydotplus: filename=pydotplus-2.0.2-py3-none-any.whl size=24575 sha256=12e3a82ec8e40bb5800157eedd8f60ae021450618de68cbf438f07564dbec6c9
#   Stored in directory: /Users/chenyuqi/Library/Caches/pip/wheels/89/e5/de/6966007cf223872eedfbebbe0e074534e72e9128c8fd4b55eb
# Successfully built pydotplus
# Installing collected packages: pydotplus
# Successfully installed pydotplus-2.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install graphviz
# Out:
# Collecting graphviz
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 4.5 MB/s eta 0:00:011
# Installing collected packages: graphviz
# Successfully installed graphviz-0.20.1
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install graphviz
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::babel==2.9.1=pyhd3eb1b0_0
#   - defaults/noarch::tifffile==2021.7.2=pyhd3eb1b0_2
#   - defaults/osx-64::daal4py==2021.3.0=py39h01d92e1_0
#   - defaults/noarch::jupyterlab_server==2.8.2=pyhd3eb1b0_0
#   - defaults/osx-64::scipy==1.7.1=py39h88652d9_2
#   - defaults/osx-64::scikit-learn==0.24.2=py39hb2f4e1b_0
#   - defaults/noarch::cookiecutter==1.7.2=pyhd3eb1b0_0
#   - defaults/noarch::imageio==2.9.0=pyhd3eb1b0_0
#   - defaults/osx-64::numba==0.54.1=py39hae1ba45_0
#   - defaults/osx-64::bottleneck==1.3.2=py39he3068b8_1
#   - defaults/osx-64::mkl_random==1.2.2=py39hb2f4e1b_0
#   - defaults/noarch::conda-repo-cli==1.0.4=pyhd3eb1b0_0
#   - defaults/osx-64::patsy==0.5.2=py39hecd8cb5_0
#   - defaults/osx-64::imagecodecs==2021.8.26=py39ha952a84_0
#   - defaults/osx-64::bkcharts==0.2=py39hecd8cb5_0
#   - defaults/osx-64::matplotlib-base==3.4.3=py39h0a11d32_0
#   - defaults/noarch::sphinx==4.2.0=pyhd3eb1b0_1
#   - defaults/osx-64::numpy==1.20.3=py39h4b4dc7a_0
#   - defaults/noarch::numpydoc==1.1.0=pyhd3eb1b0_1
#   - defaults/osx-64::astropy==4.3.1=py39hf9932de_0
#   - defaults/osx-64::pywavelets==1.1.1=py39he3068b8_4
#   - defaults/osx-64::scikit-learn-intelex==2021.3.0=py39hecd8cb5_0
#   - defaults/osx-64::h5py==3.2.1=py39h90fc2a2_0
#   - defaults/osx-64::anaconda==2021.11=py39_0
#   - defaults/osx-64::anaconda-client==1.9.0=py39hecd8cb5_0
#   - defaults/osx-64::_ipyw_jlab_nb_ext_conf==0.1.0=py39hecd8cb5_0
#   - defaults/osx-64::pytables==3.6.1=py39h648f197_1
#   - defaults/osx-64::scikit-image==0.18.3=py39hae1ba45_0
#   - defaults/osx-64::pyerfa==2.0.0=py39h9ed2024_0
#   - defaults/noarch::jupyterlab==3.2.1=pyhd3eb1b0_1
#   - defaults/osx-64::spyder==5.1.5=py39hecd8cb5_1
#   - defaults/noarch::soupsieve==2.2.1=pyhd3eb1b0_0
#   - defaults/osx-64::statsmodels==0.12.2=py39h9ed2024_0
#   - defaults/osx-64::numexpr==2.7.3=py39h5873af2_1
#   - defaults/osx-64::mkl_fft==1.3.1=py39h4ab4a9b_0
#   - defaults/noarch::conda-token==0.3.0=pyhd3eb1b0_0
#   - defaults/noarch::seaborn==0.11.2=pyhd3eb1b0_0
#   - defaults/osx-64::bokeh==2.4.1=py39hecd8cb5_0
#   - defaults/noarch::dask==2021.10.0=pyhd3eb1b0_0
#   - defaults/osx-64::conda-build==3.21.5=py39hecd8cb5_0
#   - defaults/osx-64::conda==4.10.3=py39hecd8cb5_0
#   - defaults/osx-64::pandas==1.3.4=py39h743cdd8_0
#   - defaults/noarch::anaconda-project==0.10.1=pyhd3eb1b0_0
#   - defaults/osx-64::matplotlib==3.4.3=py39hecd8cb5_0
#   - defaults/osx-64::anaconda-navigator==2.1.1=py39_0
# failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::babel==2.9.1=pyhd3eb1b0_0
#   - defaults/noarch::tifffile==2021.7.2=pyhd3eb1b0_2
#   - defaults/osx-64::daal4py==2021.3.0=py39h01d92e1_0
#   - defaults/noarch::jupyterlab_server==2.8.2=pyhd3eb1b0_0
#   - defaults/osx-64::scipy==1.7.1=py39h88652d9_2
#   - defaults/osx-64::scikit-learn==0.24.2=py39hb2f4e1b_0
#   - defaults/noarch::cookiecutter==1.7.2=pyhd3eb1b0_0
#   - defaults/noarch::imageio==2.9.0=pyhd3eb1b0_0
#   - defaults/osx-64::numba==0.54.1=py39hae1ba45_0
#   - defaults/osx-64::bottleneck==1.3.2=py39he3068b8_1
#   - defaults/osx-64::mkl_random==1.2.2=py39hb2f4e1b_0
#   - defaults/noarch::conda-repo-cli==1.0.4=pyhd3eb1b0_0
#   - defaults/osx-64::patsy==0.5.2=py39hecd8cb5_0
#   - defaults/osx-64::imagecodecs==2021.8.26=py39ha952a84_0
#   - defaults/osx-64::bkcharts==0.2=py39hecd8cb5_0
#   - defaults/osx-64::matplotlib-base==3.4.3=py39h0a11d32_0
#   - defaults/noarch::sphinx==4.2.0=pyhd3eb1b0_1
#   - defaults/osx-64::numpy==1.20.3=py39h4b4dc7a_0
#   - defaults/noarch::numpydoc==1.1.0=pyhd3eb1b0_1
#   - defaults/osx-64::astropy==4.3.1=py39hf9932de_0
#   - defaults/osx-64::pywavelets==1.1.1=py39he3068b8_4
#   - defaults/osx-64::scikit-learn-intelex==2021.3.0=py39hecd8cb5_0
#   - defaults/osx-64::h5py==3.2.1=py39h90fc2a2_0
#   - defaults/osx-64::anaconda==2021.11=py39_0
#   - defaults/osx-64::anaconda-client==1.9.0=py39hecd8cb5_0
#   - defaults/osx-64::_ipyw_jlab_nb_ext_conf==0.1.0=py39hecd8cb5_0
#   - defaults/osx-64::pytables==3.6.1=py39h648f197_1
#   - defaults/osx-64::scikit-image==0.18.3=py39hae1ba45_0
#   - defaults/osx-64::pyerfa==2.0.0=py39h9ed2024_0
#   - defaults/noarch::jupyterlab==3.2.1=pyhd3eb1b0_1
#   - defaults/osx-64::spyder==5.1.5=py39hecd8cb5_1
#   - defaults/noarch::soupsieve==2.2.1=pyhd3eb1b0_0
#   - defaults/osx-64::statsmodels==0.12.2=py39h9ed2024_0
#   - defaults/osx-64::numexpr==2.7.3=py39h5873af2_1
#   - defaults/osx-64::mkl_fft==1.3.1=py39h4ab4a9b_0
#   - defaults/noarch::conda-token==0.3.0=pyhd3eb1b0_0
#   - defaults/noarch::seaborn==0.11.2=pyhd3eb1b0_0
#   - defaults/osx-64::bokeh==2.4.1=py39hecd8cb5_0
#   - defaults/noarch::dask==2021.10.0=pyhd3eb1b0_0
#   - defaults/osx-64::conda-build==3.21.5=py39hecd8cb5_0
#   - defaults/osx-64::conda==4.10.3=py39hecd8cb5_0
#   - defaults/osx-64::pandas==1.3.4=py39h743cdd8_0
#   - defaults/noarch::anaconda-project==0.10.1=pyhd3eb1b0_0
#   - defaults/osx-64::matplotlib==3.4.3=py39hecd8cb5_0
#   - defaults/osx-64::anaconda-navigator==2.1.1=py39_0
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - graphviz
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2021.11  |           py39_0           7 KB
#     anaconda-custom            |           py39_1           4 KB
#     beautifulsoup4-4.12.2      |   py39hecd8cb5_0         215 KB
#     ca-certificates-2023.01.10 |       hecd8cb5_0         121 KB
#     cairo-1.16.0               |       h3ce6f7e_3         1.0 MB
#     certifi-2022.12.7          |   py39hecd8cb5_0         151 KB
#     expat-2.4.9                |       he9d5cce_0         127 KB
#     font-ttf-dejavu-sans-mono-2.37|       hd3eb1b0_0         335 KB
#     font-ttf-inconsolata-2.001 |       hcb22688_0          83 KB
#     font-ttf-source-code-pro-2.030|       hd3eb1b0_0         654 KB
#     font-ttf-ubuntu-0.83       |       h8b1ccd4_0         1.5 MB
#     fontconfig-2.14.1          |       hedf32ac_1         249 KB
#     fonts-anaconda-1           |       h8fa9717_0           3 KB
#     fonts-conda-ecosystem-1    |       hd3eb1b0_0           5 KB
#     fribidi-1.0.10             |       haf1e3a3_0          63 KB
#     gdk-pixbuf-2.42.8          |       h6c40b1e_2         580 KB
#     gettext-0.21.0             |       h7535e17_0         2.6 MB
#     glib-2.69.1                |       h8346a28_1         2.7 MB
#     graphite2-1.3.14           |       he9d5cce_1          82 KB
#     graphviz-2.50.0            |       h196fa6a_0         2.4 MB
#     gts-0.7.6                  |       h6759243_3         276 KB
#     harfbuzz-4.3.0             |       h3f129a2_0         1.0 MB
#     jpeg-9e                    |       h6c40b1e_1         252 KB
#     libgd-2.3.3                |       he7e2580_1         198 KB
#     librsvg-2.54.4             |       h52d90eb_0         4.3 MB
#     libtool-2.4.6              |    hcec6c5f_1009         421 KB
#     libxml2-2.9.14             |       hbf8cd5e_0         641 KB
#     lxml-4.8.0                 |   py39h65b224f_0         1.2 MB
#     openssl-1.1.1t             |       hca72f7f_0         3.3 MB
#     pango-1.50.7               |       h80fe9ab_0         523 KB
#     pcre-8.45                  |       h23ab428_0         181 KB
#     pixman-0.40.0              |       h9ed2024_1         341 KB
#     pytz-2022.7                |   py39hecd8cb5_0         210 KB
#     requests-2.28.1            |   py39hecd8cb5_1          99 KB
#     zlib-1.2.13                |       h4dc903c_0          96 KB
#     ------------------------------------------------------------
#                                            Total:        25.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/osx-64::_anaconda_depends-2021.11-py39_0
#   beautifulsoup4     pkgs/main/osx-64::beautifulsoup4-4.12.2-py39hecd8cb5_0
#   cairo              pkgs/main/osx-64::cairo-1.16.0-h3ce6f7e_3
#   expat              pkgs/main/osx-64::expat-2.4.9-he9d5cce_0
#   font-ttf-dejavu-s~ pkgs/main/noarch::font-ttf-dejavu-sans-mono-2.37-hd3eb1b0_0
#   font-ttf-inconsol~ pkgs/main/noarch::font-ttf-inconsolata-2.001-hcb22688_0
#   font-ttf-source-c~ pkgs/main/noarch::font-ttf-source-code-pro-2.030-hd3eb1b0_0
#   font-ttf-ubuntu    pkgs/main/noarch::font-ttf-ubuntu-0.83-h8b1ccd4_0
#   fontconfig         pkgs/main/osx-64::fontconfig-2.14.1-hedf32ac_1
#   fonts-anaconda     pkgs/main/noarch::fonts-anaconda-1-h8fa9717_0
#   fonts-conda-ecosy~ pkgs/main/noarch::fonts-conda-ecosystem-1-hd3eb1b0_0
#   fribidi            pkgs/main/osx-64::fribidi-1.0.10-haf1e3a3_0
#   gdk-pixbuf         pkgs/main/osx-64::gdk-pixbuf-2.42.8-h6c40b1e_2
#   gettext            pkgs/main/osx-64::gettext-0.21.0-h7535e17_0
#   glib               pkgs/main/osx-64::glib-2.69.1-h8346a28_1
#   graphite2          pkgs/main/osx-64::graphite2-1.3.14-he9d5cce_1
#   graphviz           pkgs/main/osx-64::graphviz-2.50.0-h196fa6a_0
#   gts                pkgs/main/osx-64::gts-0.7.6-h6759243_3
#   harfbuzz           pkgs/main/osx-64::harfbuzz-4.3.0-h3f129a2_0
#   libgd              pkgs/main/osx-64::libgd-2.3.3-he7e2580_1
#   librsvg            pkgs/main/osx-64::librsvg-2.54.4-h52d90eb_0
#   libtool            pkgs/main/osx-64::libtool-2.4.6-hcec6c5f_1009
#   lxml               pkgs/main/osx-64::lxml-4.8.0-py39h65b224f_0
#   numpy-base         pkgs/main/osx-64::numpy-base-1.20.3-py39he0bd621_0
#   pango              pkgs/main/osx-64::pango-1.50.7-h80fe9ab_0
#   pcre               pkgs/main/osx-64::pcre-8.45-h23ab428_0
#   pixman             pkgs/main/osx-64::pixman-0.40.0-h9ed2024_1
#   pytz               pkgs/main/osx-64::pytz-2022.7-py39hecd8cb5_0
#   requests           pkgs/main/osx-64::requests-2.28.1-py39hecd8cb5_1
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2021.10.26-hecd8cb5_2 --> 2023.01.10-hecd8cb5_0
#   certifi                          2021.10.8-py39hecd8cb5_0 --> 2022.12.7-py39hecd8cb5_0
#   jpeg                                        9d-h9ed2024_0 --> 9e-h6c40b1e_1
#   libxml2                                 2.9.12-hcdb78fc_0 --> 2.9.14-hbf8cd5e_0
#   openssl                                 1.1.1l-h9ed2024_0 --> 1.1.1t-hca72f7f_0
#   zlib                                    1.2.11-h1de35cc_3 --> 1.2.13-h4dc903c_0
#
# The following packages will be DOWNGRADED:
#
#   anaconda                                   2021.11-py39_0 --> custom-py39_1
#
#
#
# Downloading and Extracting Packages
# lxml-4.8.0           | 1.2 MB    | ##################################### | 100%
# libgd-2.3.3          | 198 KB    | ##################################### | 100%
# gts-0.7.6            | 276 KB    | ##################################### | 100%
# beautifulsoup4-4.12. | 215 KB    | ##################################### | 100%
# anaconda-custom      | 4 KB      | ##################################### | 100%
# cairo-1.16.0         | 1.0 MB    | ##################################### | 100%
# pcre-8.45            | 181 KB    | ##################################### | 100%
# fontconfig-2.14.1    | 249 KB    | ##################################### | 100%
# pango-1.50.7         | 523 KB    | ##################################### | 100%
# graphite2-1.3.14     | 82 KB     | ##################################### | 100%
# libxml2-2.9.14       | 641 KB    | ##################################### | 100%
# fonts-conda-ecosyste | 5 KB      | ##################################### | 100%
# harfbuzz-4.3.0       | 1.0 MB    | ##################################### | 100%
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##################################### | 100%
# zlib-1.2.13          | 96 KB     | ##################################### | 100%
# _anaconda_depends-20 | 7 KB      | ##################################### | 100%
# openssl-1.1.1t       | 3.3 MB    | ##################################### | 100%
# glib-2.69.1          | 2.7 MB    | ##################################### | 100%
# certifi-2022.12.7    | 151 KB    | ##################################### | 100%
# font-ttf-dejavu-sans | 335 KB    | ##################################### | 100%
# font-ttf-inconsolata | 83 KB     | ##################################### | 100%
# graphviz-2.50.0      | 2.4 MB    | ##################################### | 100%
# pixman-0.40.0        | 341 KB    | ##################################### | 100%
# fonts-anaconda-1     | 3 KB      | ##################################### | 100%
# jpeg-9e              | 252 KB    | ##################################### | 100%
# pytz-2022.7          | 210 KB    | ##################################### | 100%
# expat-2.4.9          | 127 KB    | ##################################### | 100%
# librsvg-2.54.4       | 4.3 MB    | ##################################### | 100%
# gettext-0.21.0       | 2.6 MB    | ##################################### | 100%
# ca-certificates-2023 | 121 KB    | ##################################### | 100%
# fribidi-1.0.10       | 63 KB     | ##################################### | 100%
# requests-2.28.1      | 99 KB     | ##################################### | 100%
# gdk-pixbuf-2.42.8    | 580 KB    | ##################################### | 100%
# font-ttf-source-code | 654 KB    | ##################################### | 100%
# libtool-2.4.6        | 421 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: failed
#
# RemoveError: 'requests' is a dependency of conda and cannot be removed from
# conda's operating environment.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.tree import DecisionTreeClassifier

# Separate the predictor values and the DV values into X and y respectively
DV = 'fraud_bool-1'
y = df_nontestData[DV]
X = df_nontestData.drop(columns=[DV])

from sklearn.tree import export_graphviz
from io import StringIO
import pydotplus
from IPython.display import Image

# A user-defined function summary_tree to display a classification tree
def summary_tree(model_object):
    dot_data = StringIO()
    export_graphviz(model_object, out_file=dot_data, filled=True,
                  rounded=True, special_characters=True, feature_names=X.columns.values,
                  class_names=['0', '1'])
    graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
    output_imagefile = 'tree.png'
    graph.write_png(output_imagefile)
    return output_imagefile

# %%
# Run Classification tree with k-fold cross validation with k=5
kfolds = 5

# Here we specify within which range of depths we will search for the best pruned tree
maximum_depth = 10
minimum_depth = 1

param_grid = {'max_depth': list(range(minimum_depth, maximum_depth+1))}

# Set n_jobs to be -1 to run on all CPU cores.
# The search criterion is to find the model that maximizes 
# whatever the scoring function - for this case roc_auc - returns.

from sklearn.model_selection import GridSearchCV

gridsearch = GridSearchCV(DecisionTreeClassifier(criterion='entropy', random_state=1), param_grid, scoring='roc_auc', cv=kfolds, n_jobs=-1)
gridsearch.fit(X,y)
clf_BPT = gridsearch.best_estimator_

# Display the resulting best pruned tree
Image(summary_tree(clf_BPT))
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# /var/folders/w2/vgv7y_vj5s7bhsnxyd_jzg8m0000gn/T/ipykernel_46199/669023899.py in <module>
#      19
#      20 # Display the resulting best pruned tree
# ---> 21 Image(summary_tree(clf_BPT))
#
# /var/folders/w2/vgv7y_vj5s7bhsnxyd_jzg8m0000gn/T/ipykernel_46199/3299693481.py in summary_tree(model_object)
#      19     graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
#      20     output_imagefile = 'tree.png'
# ---> 21     graph.write_png(output_imagefile)
#      22     return output_imagefile
#
# /opt/anaconda3/lib/python3.9/site-packages/pydotplus/graphviz.py in <lambda>(path, f, prog)
#    1808                 lambda path,
#    1809                 f=frmt,
# -> 1810                 prog=self.prog: self.write(path, format=f, prog=prog)
#    1811             )
#    1812
#
# /opt/anaconda3/lib/python3.9/site-packages/pydotplus/graphviz.py in write(self, path, prog, format)
#    1916
#    1917             else:
# -> 1918                 fobj.write(self.create(prog, format))
#    1919         finally:
#    1920             if close:
#
# /opt/anaconda3/lib/python3.9/site-packages/pydotplus/graphviz.py in create(self, prog, format)
#    1957             self.progs = find_graphviz()
#    1958             if self.progs is None:
# -> 1959                 raise InvocationException(
#    1960                     'GraphViz\'s executables not found')
#    1961
#
# InvocationException: GraphViz's executables not found

# %%
# Display the level of depth of the best pruned tree
print(clf_BPT.get_depth())

# y_test_actual is the actual values of the DV in the test partition
y_test_actual = df_testData[DV]

# X_test is the predictor values in the test partition
X_test = df_testData.drop(columns=[DV])


# Get the AUC of the best pruned tree model
from sklearn.metrics import roc_auc_score
print(roc_auc_score(y_test_actual, clf_BPT.predict_proba(X_test)[:,1]))

# %% [markdown]
# # Part 8 K-Nearest Neighbors Model

# %%
from sklearn.neighbors import KNeighborsClassifier

# Separate the predictor values and the DV values into X and y respectively
DV = 'fraud_bool-1'
y = df_nontestData[DV]
X = df_nontestData.drop(columns=[DV])


# Report the performance over the test partition
X_test = df_testData.drop(columns=DV)
y_test = df_testData[DV]

from sklearn import metrics

# %%
# Run Nearest neighbor with 5-fold cross validation
kfolds = 5

# We first define the search scope. k (k-th nearest neighbor) will be increased from 1 to max_k
max_k = 200

param_grid = {'n_neighbors': list(range(1, max_k+1))}


# Set n_jobs to be -1 to run  on all CPU cores.
# The search criterion is to find the model that maximizes 
# whatever the scoring function - for this case roc_auc - returns.

from sklearn.model_selection import GridSearchCV

gridsearch = GridSearchCV(KNeighborsClassifier(metric='euclidean'), param_grid, scoring='roc_auc', cv=kfolds, n_jobs=-1)
gridsearch.fit(X,y)
clf_bestkNN = gridsearch.best_estimator_
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/w2/vgv7y_vj5s7bhsnxyd_jzg8m0000gn/T/ipykernel_44162/279660354.py in <module>
#      15
#      16 gridsearch = GridSearchCV(KNeighborsClassifier(metric='euclidean'), param_grid, scoring='roc_auc', cv=kfolds, n_jobs=-1)
# ---> 17 gridsearch.fit(X,y)
#      18 clf_bestkNN = gridsearch.best_estimator_
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     839                 return results
#     840
# --> 841             self._run_search(evaluate_candidates)
#     842
#     843             # multimetric is determined here because in the case of a callable
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1294     def _run_search(self, evaluate_candidates):
#    1295         """Search all candidates in param_grid"""
# -> 1296         evaluate_candidates(ParameterGrid(self.param_grid))
#    1297
#    1298
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     793                               n_splits, n_candidates, n_candidates * n_splits))
#     794
# --> 795                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     796                                                        X, y,
#     797                                                        train=train, test=test,
#
# /opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1054
#    1055             with self._backend.retrieval_context():
# -> 1056                 self.retrieve()
#    1057             # Make sure that we get a last message telling us we are done
#    1058             elapsed_time = time.time() - self._start_time
#
# /opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in retrieve(self)
#     933             try:
#     934                 if getattr(self._backend, 'supports_timeout', False):
# --> 935                     self._output.extend(job.get(timeout=self.timeout))
#     936                 else:
#     937                     self._output.extend(job.get())
#
# /opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# /opt/anaconda3/lib/python3.9/concurrent/futures/_base.py in result(self, timeout)
#     438                     return self.__get_result()
#     439
# --> 440                 self._condition.wait(timeout)
#     441
#     442                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /opt/anaconda3/lib/python3.9/threading.py in wait(self, timeout)
#     310         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#     314             else:
#
# KeyboardInterrupt:

# %%
# Display the optimal k (k-th nearest neighbor)
print(clf_bestkNN.n_neighbors)

# y_test_actual is the actual values of the DV in the test partition
y_test_actual = df_testData[DV]

# X_test is the predictor values in the test partition
X_test = df_testData.drop(columns=[DV])

# Get the AUC of the final selected k-NN model
from sklearn.metrics import roc_auc_score
print(roc_auc_score(y_test_actual, clf_bestkNN.predict_proba(X_test)[:,1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/w2/vgv7y_vj5s7bhsnxyd_jzg8m0000gn/T/ipykernel_44162/3454790501.py in <module>
#       1 # Display the optimal k (k-th nearest neighbor)
# ----> 2 print(clf_bestkNN.n_neighbors)
#       3
#       4 # y_test_actual is the actual values of the DV in the test partition
#       5 y_test_actual = df_testData[DV]
#
# NameError: name 'clf_bestkNN' is not defined

# %% [markdown]
# # Part 9 Neutral Network

# %%
from sklearn.neural_network import MLPClassifier

# Separate the predictor values and the DV values into X and y respectively
DV = 'fraud_bool-1'
y = df_nontestData[DV]
X = df_nontestData.drop(columns=[DV])

# A user-defined function summary_tree to display a neural network model
def summary_nn(model_object):
    coef_structure = [coef.shape for coef in model_object.coefs_]

    n_hidden_nodes = coef_structure[0][1]
    n_input_nodes = coef_structure[0][0]

    print('Neural Network Model Summary \n')
  
    print('Section 0. Penalty level alpha:', model_object.alpha)

    print('\nSection 1. Input (I) -> Hidden (H) - Weight (W): \n')

    for i in range(n_input_nodes):
        for j in range(n_hidden_nodes):
            print('I:', i+1, '-> H:', j+1, '- W:', model_object.coefs_[0][i][j])

    print('\nSection 2. Hidden (H) - Node Bias (B): \n')
    for j in range(n_hidden_nodes):
        print('H:', j+1, '- B:', model_object.intercepts_[0][j])

    print('\nSection 3. Hidden (H) -> Output (O) - Weight (W): \n')
    for j in range(n_hidden_nodes):
        print('H:', j+1, '-> O - W:', model_object.coefs_[1][j][0])
    
    print('\nSection 4. Output (O) - Node Bias (B): \n')
    print('O - B:', model_object.intercepts_[1][0])

# %%
# Run Neural Network with k-fold cross validation with k=5
kfolds = 5

# Here we specify within which range of the number of nodes on the hidden layer we will search for the best network model
min_hls = 1
max_hls = 10

# Here we specify within which range of penalty level we will search for the best network model
min_alpha = 0.0001
max_alpha = 10
n_alpha = 10

# Define the parameter grid for search
import numpy as np
param_grid = {'hidden_layer_sizes':np.arange(min_hls, max_hls), 'alpha': list(np.linspace(min_alpha, max_alpha, num=n_alpha))}


# Set n_jobs to be -1 to run  on all CPU cores.
# The search criterion is to find the model that maximizes 
# whatever the scoring function - for this case roc_auc - returns.

from sklearn.model_selection import GridSearchCV

gridsearch = GridSearchCV(MLPClassifier(solver='lbfgs', max_iter=4000, random_state=1), param_grid, scoring='roc_auc', cv=kfolds, n_jobs=-1)
gridsearch.fit(X,y)
clf_NN = gridsearch.best_estimator_

# Display the resulting best network modele
summary_nn(clf_NN)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/w2/vgv7y_vj5s7bhsnxyd_jzg8m0000gn/T/ipykernel_44162/242430917.py in <module>
#      23
#      24 gridsearch = GridSearchCV(MLPClassifier(solver='lbfgs', max_iter=4000, random_state=1), param_grid, scoring='roc_auc', cv=kfolds, n_jobs=-1)
# ---> 25 gridsearch.fit(X,y)
#      26 clf_NN = gridsearch.best_estimator_
#      27
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     839                 return results
#     840
# --> 841             self._run_search(evaluate_candidates)
#     842
#     843             # multimetric is determined here because in the case of a callable
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1294     def _run_search(self, evaluate_candidates):
#    1295         """Search all candidates in param_grid"""
# -> 1296         evaluate_candidates(ParameterGrid(self.param_grid))
#    1297
#    1298
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     793                               n_splits, n_candidates, n_candidates * n_splits))
#     794
# --> 795                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     796                                                        X, y,
#     797                                                        train=train, test=test,
#
# /opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1054
#    1055             with self._backend.retrieval_context():
# -> 1056                 self.retrieve()
#    1057             # Make sure that we get a last message telling us we are done
#    1058             elapsed_time = time.time() - self._start_time
#
# /opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in retrieve(self)
#     933             try:
#     934                 if getattr(self._backend, 'supports_timeout', False):
# --> 935                     self._output.extend(job.get(timeout=self.timeout))
#     936                 else:
#     937                     self._output.extend(job.get())
#
# /opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# /opt/anaconda3/lib/python3.9/concurrent/futures/_base.py in result(self, timeout)
#     438                     return self.__get_result()
#     439
# --> 440                 self._condition.wait(timeout)
#     441
#     442                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /opt/anaconda3/lib/python3.9/threading.py in wait(self, timeout)
#     310         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#     314             else:
#
# KeyboardInterrupt:

# %%
# Display the level of depth of the best pruned tree
# print(clf_BPT.get_depth())

# y_test_actual is the actual values of the DV in the test partition
y_test_actual = df_testData[DV]

# X_test is the predictor values in the test partition
X_test = df_testData.drop(columns=[DV])

# Get the AUC of the best pruned tree model
from sklearn.metrics import roc_auc_score
print(roc_auc_score(y_test_actual, clf_NN.predict_proba(X_test)[:,1]))

# print(clf_NN.predict_proba(X_test)[:,1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/w2/vgv7y_vj5s7bhsnxyd_jzg8m0000gn/T/ipykernel_44162/1829753456.py in <module>
#      10 # Get the AUC of the best pruned tree model
#      11 from sklearn.metrics import roc_auc_score
# ---> 12 print(roc_auc_score(y_test_actual, clf_NN.predict_proba(X_test)[:,1]))
#      13
#      14 # print(clf_NN.predict_proba(X_test)[:,1])
#
# NameError: name 'clf_NN' is not defined

# %%
# # Display the confusion matrix over the test partition
# print(metrics.confusion_matrix(y_test_actual, y_test_predicted))

# print(metrics.classification_report(y_test_actual,y_test_predicted))

# # Display the accuracy over the test partition
# print(clf_optimal.score(X_test, y_test_actual))
